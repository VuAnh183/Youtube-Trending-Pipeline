# %%
import pandas as pd
import json

file_path = "../data/raw/test.json"

# %%
with open(file_path, "r") as f:
    data = json.load(f)

type(data)
# Out:
# dict

# %%
with open(file_path, "r") as f:
    data = json.load(f)

filtered_df = pd.json_normalize(data['items'])

filtered_df
# Out:
#             kind                         etag           id  \
# 0  youtube#video  Qlgk_rKR1Y12wxs4S56gaLilhuY  Eg4hjfjS0YQ
# 1  youtube#video  EBpZz7NcuP8Zvnsvb0lammWLXrw  apT3OoZ58V8
# 2  youtube#video  H8mVCFdK0IvXeIRGZ3b15MFY5q8  q1wN-fPznWM
#
#     snippet.publishedAt         snippet.channelId  \
# 0  2025-10-28T16:00:34Z  UCIEcq0eG63LS-4J9M1qNj9Q
# 1  2025-10-28T10:14:14Z  UC_i8X3p8oZNaik8X513Zn1Q
# 2  2025-10-29T00:44:11Z  UCiFyJ_EBmF2XJuR9buWE_3A
#
#                                        snippet.title  \
# 0  Charlotte Cardin - Tant pis pour elle [Officia...
# 1  CHERS PARENTS Bande Annonce (2026) Arnaud Ducr...
# 2  🔴Tacos Tuesday ADMIN ABUSE + Nouveaux Brainrots !
#
#                                  snippet.description  \
# 0  'Tant pis pour elle' is available now: \nhttps...
# 1  ✩ Les Films à VOIR ?  Ils sont ICI ► https://w...
# 2  En route vers les 7 millions d'abonnés ! Roblo...
#
#                    snippet.thumbnails.default.url  \
# 0  https://i.ytimg.com/vi/Eg4hjfjS0YQ/default.jpg
# 1  https://i.ytimg.com/vi/apT3OoZ58V8/default.jpg
# 2  https://i.ytimg.com/vi/q1wN-fPznWM/default.jpg
#
#    snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                               120                                 90  ...
# 1                               120                                 90  ...
# 2                               120                                 90  ...
#
#   snippet.categoryId  snippet.liveBroadcastContent  snippet.defaultLanguage  \
# 0                 10                          none                       fr
# 1                  1                          none                       fr
# 2                 20                          none                       fr
#
#                              snippet.localized.title  \
# 0  Charlotte Cardin - Tant pis pour elle [Officia...
# 1  CHERS PARENTS Bande Annonce (2026) Arnaud Ducr...
# 2  🔴Tacos Tuesday ADMIN ABUSE + Nouveaux Brainrots !
#
#                        snippet.localized.description  \
# 0  'Tant pis pour elle' is available now: \nhttps...
# 1  ✩ Les Films à VOIR ?  Ils sont ICI ► https://w...
# 2  En route vers les 7 millions d'abonnés ! Roblo...
#
#    snippet.defaultAudioLanguage statistics.viewCount  statistics.likeCount  \
# 0                            en               142064                  8582
# 1                            fr                49744                   315
# 2                         fr-FR               593090                 25366
#
#    statistics.favoriteCount statistics.commentCount
# 0                         0                     446
# 1                         0                      19
# 2                         0                     624
#
# [3 rows x 34 columns]

# %% [markdown]
# ***Data features to keep***
#
# - items['id']
# - items['snippet.publishedAt']
# - items['snippet.channelId']
# - items['snippet.title']
# - items['snippet.channelTitle']
# - items['snippet.categoryId']
# - items['statistics.viewCount']
# - items['statistics.likeCount']
# - items['statistics.commentCount']

# %%
columns_to_keep = [
    'id',
    'snippet.publishedAt',
    'snippet.channelId',
    'snippet.title',
    'snippet.channelTitle',
    'snippet.categoryId',
    'statistics.viewCount',
    'statistics.likeCount',
    'statistics.commentCount'
]

# %%
clean_df = filtered_df[columns_to_keep].copy()

clean_df
# Out:
#             id   snippet.publishedAt         snippet.channelId  \
# 0  Eg4hjfjS0YQ  2025-10-28T16:00:34Z  UCIEcq0eG63LS-4J9M1qNj9Q
# 1  apT3OoZ58V8  2025-10-28T10:14:14Z  UC_i8X3p8oZNaik8X513Zn1Q
# 2  q1wN-fPznWM  2025-10-29T00:44:11Z  UCiFyJ_EBmF2XJuR9buWE_3A
#
#                                        snippet.title snippet.channelTitle  \
# 0  Charlotte Cardin - Tant pis pour elle [Officia...     Charlotte Cardin
# 1  CHERS PARENTS Bande Annonce (2026) Arnaud Ducr...            FilmsActu
# 2  🔴Tacos Tuesday ADMIN ABUSE + Nouveaux Brainrots !        Unchained_Off
#
#   snippet.categoryId statistics.viewCount statistics.likeCount  \
# 0                 10               142064                 8582
# 1                  1                49744                  315
# 2                 20               593090                25366
#
#   statistics.commentCount
# 0                     446
# 1                      19
# 2                     624

# %% [markdown]
# ***Rename all the fields***

# %%
clean_df.rename(columns={
    'id': 'video_id',
    'snippet.title': 'title',
    'snippet.publishedAt': 'published_at',
    'snippet.channelId': 'channel_id',
    'snippet.channelTitle': 'channel_title',
    'snippet.categoryId': 'category_id',
    'statistics.viewCount': 'views',
    'statistics.likeCount': 'likes',
    'statistics.commentCount': 'comments'
}, inplace=True)

# %%
clean_df
# Out:
#       video_id          published_at                channel_id  \
# 0  Eg4hjfjS0YQ  2025-10-28T16:00:34Z  UCIEcq0eG63LS-4J9M1qNj9Q
# 1  apT3OoZ58V8  2025-10-28T10:14:14Z  UC_i8X3p8oZNaik8X513Zn1Q
# 2  q1wN-fPznWM  2025-10-29T00:44:11Z  UCiFyJ_EBmF2XJuR9buWE_3A
#
#                                                title     channel_title  \
# 0  Charlotte Cardin - Tant pis pour elle [Officia...  Charlotte Cardin
# 1  CHERS PARENTS Bande Annonce (2026) Arnaud Ducr...         FilmsActu
# 2  🔴Tacos Tuesday ADMIN ABUSE + Nouveaux Brainrots !     Unchained_Off
#
#   category_id   views  likes comments
# 0          10  142064   8582      446
# 1           1   49744    315       19
# 2          20  593090  25366      624

# %% [markdown]
# ***Convert types***

# %%
clean_df['views'] = clean_df['views'].astype(int)
clean_df['likes'] = clean_df['likes'].astype(int)
clean_df['comments'] = clean_df['comments'].astype(int)
clean_df['published_at'] = pd.to_datetime(clean_df['published_at'])
# Out:
# /tmp/ipykernel_10884/2933585613.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['views'] = clean_df['views'].astype(int)
# /tmp/ipykernel_10884/2933585613.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['likes'] = clean_df['likes'].astype(int)
# /tmp/ipykernel_10884/2933585613.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['comments'] = clean_df['comments'].astype(int)
# /tmp/ipykernel_10884/2933585613.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['published_at'] = pd.to_datetime(clean_df['published_at'])

# %%
clean_df['title'][1]
# Out:
# 'CHERS PARENTS Bande Annonce (2026) Arnaud Ducret, Comédie'
